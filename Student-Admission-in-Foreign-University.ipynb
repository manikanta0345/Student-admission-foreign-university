# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Mani\Downloads\admission_predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.shape
# Out:
# (500, 9)

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.describe().T
# Out:
#                    count       mean         std     min       25%     50%  \
# Serial No.         500.0  250.50000  144.481833    1.00  125.7500  250.50
# GRE Score          500.0  316.47200   11.295148  290.00  308.0000  317.00
# TOEFL Score        500.0  107.19200    6.081868   92.00  103.0000  107.00
# University Rating  500.0    3.11400    1.143512    1.00    2.0000    3.00
# SOP                500.0    3.37400    0.991004    1.00    2.5000    3.50
# LOR                500.0    3.48400    0.925450    1.00    3.0000    3.50
# CGPA               500.0    8.57644    0.604813    6.80    8.1275    8.56
# Research           500.0    0.56000    0.496884    0.00    0.0000    1.00
# Chance of Admit    500.0    0.72174    0.141140    0.34    0.6300    0.72
#
#                       75%     max
# Serial No.         375.25  500.00
# GRE Score          325.00  340.00
# TOEFL Score        112.00  120.00
# University Rating    4.00    5.00
# SOP                  4.00    5.00
# ...

# %% [markdown]
# # FINDING THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# # DROPING THE UNNECESSARY COLUMNS FOR ANALYSIS

# %%
df = df.drop(columns = ['Serial No.'])

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.shape
# Out:
# (500, 8)

# %%
df=df.rename(columns={'GRE Score':'GRE','TOEFL Score':'TOEFL','LOR ':'LOR',
'Chance of Admit ':'Probability'})

# %% [markdown]
# # CHECKING FOR THE "OUTLIERS"

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['GRE'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['TOEFL'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['LOR'])
plt.show()

# %%
df.LOR.value_counts()
# Out:
# 3.0    99
# 4.0    94
# 3.5    86
# 4.5    63
# 2.5    50
# 5.0    50
# 2.0    46
# 1.5    11
# 1.0     1
# Name: LOR, dtype: int64

# %% [markdown]
# # TREATING THE OUTLIERS BY USING WINSORIZOR TECHNIQUE

# %%
plt.figure(figsize=(20,10))
from feature_engine.outliers import Winsorizer
LOR= Winsorizer(capping_method = 'gaussian',tail ='both' ,fold =1.5 ,variables =['LOR'])
df['LOR'] = LOR.fit_transform(df[['LOR']])
sns.boxplot(x = df['LOR'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['SOP'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['CGPA'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x= df['Probability'])
plt.show()

# %%
df.Probability.value_counts().index
# Out:
# Float64Index([0.71, 0.64, 0.73, 0.72, 0.79, 0.78, 0.76, 0.62, 0.94,  0.7, 0.68,
#                0.8, 0.74, 0.93, 0.65, 0.89, 0.84, 0.67, 0.61, 0.86, 0.57, 0.77,
#               0.91, 0.82, 0.69, 0.92, 0.81, 0.66,  0.9, 0.58, 0.87, 0.54, 0.75,
#               0.96, 0.59, 0.63, 0.52, 0.56, 0.85, 0.49, 0.53, 0.46, 0.47, 0.95,
#               0.42, 0.88, 0.97, 0.83, 0.44, 0.45, 0.48, 0.51,  0.6,  0.5, 0.55,
#               0.34, 0.38, 0.36, 0.43, 0.39, 0.37],
#              dtype='float64')

# %%
plt.figure(figsize=(20,10))
from feature_engine.outliers import Winsorizer
Probability= Winsorizer(capping_method = 'gaussian',tail ='both' ,fold =1.5 ,variables =['Probability'])
df['Probability'] = Probability.fit_transform(df[['Probability']])
sns.boxplot(x = df['Probability'])
plt.show()

# %% [markdown]
# # DATA VISUALIZATION

# %%
for i in df.columns:
    plt.figure(figsize=(15,10))
    print(sns.countplot(x = i,data =df))
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
plt.figure(figsize=(15,10))
fig=plt.hist(df['GRE'],rwidth=0.9)
plt.xlabel('Distribution of GRE scores')
plt.xlabel('GRE scores')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(df['TOEFL'],rwidth = 0.9)
plt.xlabel('Distribution of GRE scores')
plt.xlabel('TOEFL scores')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(df['University Rating'],rwidth = 0.9)
plt.xlabel('Distribution of University Rating')
plt.xlabel('University Rating')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(df['SOP'],rwidth=0.8)
plt.xlabel('Distribution of SOP')
plt.xlabel('SOP of Rating')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(df['LOR'],rwidth = 0.9)
plt.xlabel('Distribution of LOR Rating')
plt.xlabel('LOR Rating')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.hist(df['CGPA'],rwidth = 0.9)
plt.xlabel('Distribution of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "GRE",y= "TOEFL",data = df, hue = "LOR",palette = 'Dark2_r')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "GRE",y= "University Rating",data = df, hue = "LOR",palette = 'rainbow_r')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "GRE",y= "SOP",data = df, hue = "LOR",palette = 'Blues')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "GRE",y= "Probability",data = df, hue = "LOR",palette = 'seismic')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "TOEFL",y= "University Rating",data = df, hue = "LOR",palette = 'flag')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "TOEFL",y= "SOP",data = df, hue = "LOR",palette = 'rocket')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "TOEFL",y= "LOR",data = df, hue = "LOR",palette = 'flag')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "TOEFL",y= "Probability",data = df, hue = "LOR",palette = 'flag')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "LOR",y= "Probability",data = df, hue = "LOR",palette = 'flag')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.scatterplot(x = "LOR",y= "CGPA",data = df, hue = "LOR",palette = 'flag')
plt.show()

# %%
plt.figure(figsize=(17,10))
sns.pairplot(data=df,hue='Research',)
plt.show()

# %%
df_copy=df.copy(deep=True)

# %%
df_copy[['GRE','TOEFL','University Rating','SOP','LOR','CGPA']]=df_copy[['GRE',
'TOEFL','University Rating','SOP','LOR','CGPA']].replace(0,np.NaN)

# %%
x=df_copy.drop('Probability',axis='columns')

# %%
y=df_copy['Probability']

# %% [markdown]
# # Estimating Machine learning algorithm for the best fit.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
def find_best_model(x,y):
    models={
        'linear_regression':{
            'model':LinearRegression(),
            'parameters': {
                'normalize':[True,False]
            }
        },
        
        'Lasso ':{
            'model':Lasso(),
            'parameters':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'svr':{
            'model':SVR(),
            'parameters':{
                'gamma':['auto','scale']
            }
        },
        'decision_tree':{
            'model':DecisionTreeRegressor(),
            'parameters':{
                'criterion':['mse','friedman_mse'],
                'splitter':['best','random']
            }
        },
        'random_forest':{
            'model':RandomForestRegressor(criterion='mse'),
            'parameters':{
                'n_estimators':[5,10,15,20]
            }
        },
        'knn':{
            'model':KNeighborsRegressor(algorithm='auto'),
            'parameters':{
                'n_neighbors':[2,5,10,20]
            }
        }
    }
    scores=[]
    for model_name,model_params in models.items():
        gs=GridSearchCV(model_params['model'],model_params['parameters'],cv=5,
return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model':model_name,
            'best_parameters':gs.best_params_,
            'score':gs.best_score_
        })
    return pd.DataFrame(scores,columns=['model','best_parameters','score'])
find_best_model(x,y)
# Out:
#                model                                    best_parameters  \
# 0  linear_regression                                {'normalize': True}
# 1             Lasso                 {'alpha': 1, 'selection': 'random'}
# 2                svr                                 {'gamma': 'scale'}
# 3      decision_tree  {'criterion': 'friedman_mse', 'splitter': 'best'}
# 4      random_forest                               {'n_estimators': 20}
# 5                knn                                {'n_neighbors': 20}
#
#       score
# 0  0.820310
# 1  0.147788
# 2  0.656221
# 3  0.666125
# 4  0.795735
# 5  0.737711

# %% [markdown]
# ## By considering Linear regression, Lasso Regression, Support vector Regressor, Decision tree, Random Forest, KNearst Neighbor Algorithms.

# %% [markdown]
# ### LINEAR REGRESSION IS GIVING THE BEST ACCURACY

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(LinearRegression(normalize=True),x,y,cv=5)
print('Highest Accuracy : {}%'.format(round(sum(scores)*100/len(scores)),3))
# Out:
# Highest Accuracy : 82%

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=5)
print('length of x_train :',len(x_train))
print('length of x_train :',len(x_test))
# Out:
# length of x_train : 400
# length of x_train : 100

# %%
model=LinearRegression(normalize=True)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8328269964546792

# %% [markdown]
# # Prediction 1

# %% [markdown]
# ### Input in the form : GRE,TOEFL,University Rating,SOP,LOR,CGPA,Research

# %%
print('chance of getting into UCLA is {} %'.format(round(model.predict([[322,110,3,3.5,2.5,8.67,1]])[0]*100,3)))
# Out:
# chance of getting into UCLA is 74.617 %

# %% [markdown]
# # Prediction 2

# %% [markdown]
# ### Input in the form : GRE,TOEFL,University Rating,SOP,LOR,CGPA,Research

# %%
print('chance of getting into UCLA is {} %'.format(round(model.predict([[320,115,3,4.0,4.5,9.24,0]])[0]*100,3)))
# Out:
# chance of getting into UCLA is 82.074 %
